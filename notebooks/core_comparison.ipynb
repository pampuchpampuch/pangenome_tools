# %%
from pgtools import panaroo_parser
from pgtools.gff_parser import parse_gff, parse_GFFs_dir, Pangenome_Gffs
from pgtools.gfa_parser import parse_gfa1
from pgtools.maf_parser import parse_maf, MAF
from pgtools.utils import intersection_len, contains
from pgtools.pangenome import Pangenome
import os
import argparse
from Bio.Seq import Seq

# %%
maf_dir = "/home/pampuch/studia/magisterka/test_data/klebsiella_subset_old/panaroo_new.maf"
gff_dir = "/home/pampuch/studia/magisterka/test_data/klebsiella_subset_old/gff/"

# %%
pg_maf = parse_maf(maf_dir)
pg_maf = MAF(list(pg_maf.seq_collections)[:30])

# %%
pg_maf.detect_soft_core()

# %%
for seq_coll in pg_maf.seq_collections:
    print(seq_coll.soft_core)
# Out:
# False
# False
# True
# True
# False
# False
# True
# False
# True
# True
# False
# True
# False
# True
# False
# False
# True
# True
# False
# True
# False
# False
# False
# True
# True
# False
# False
# True
# False
# True

# %%
pg_maf.map_to_gff(gff_dir)

# %%
def annotations_to_csv(pg, gff_dir, csv_name = "annotations_summary.csv"):
    res_csv = open(csv_name, "w")
    res_csv.write("cluster id,cluster size,core status,seq name,mapped annotations\n")
    res_csv.flush()
    pg.detect_soft_core()
    pg.map_to_gff(gff_dir)
    for seq_coll in pg.seq_collections:
        id = seq_coll.id
        clust_size = len(seq_coll)
        core_status = seq_coll.soft_core
        for seq in seq_coll.sequences:
            # annotation len is also an iimportant aspect, but can be easily retrived from gff file
            # print(seq.seq_name, [ann.annotation_id for ann in seq.mapped_annotations], seq_coll.soft_core)
            annots = ";".join([ann.annotation_id for ann in seq.mapped_annotations])
            res_csv.write(f"{id},{clust_size},{core_status},{seq.seq_name},{annots}\n")
            res_csv.flush()
    res_csv.close()

# %%
annotations_to_csv(pg_maf, gff_dir)

# %%
for seq_coll in pg_maf.seq_collections:
    print(seq_coll.id)
    for seq in seq_coll.sequences:
        print(seq.seq_name, [ann.annotation_id for ann in seq.mapped_annotations], seq_coll.soft_core)
# Out:
# 300
# 5150_1_3.contig00070 ['AOMCCKAJ_05284'] False
# 5151_2_6.contig00040 ['NALFBGJE_03847'] False
# 5151_6_6.contig00050 ['NJAAJKJA_05060'] False
# 5193_2_6.contig00088 ['FGIHKDBE_05317'] False
# 5197_7_4.contig00091 ['IMGDPOBN_05180'] False
# 5235_1_4.contig00216 [] False
# 5235_6_12.contig00298 ['LIDJBJFH_04408'] False
# 5299_1_3.contig00161 ['OBOFFKJP_04413'] False
# 5299_7_4.contig00195 ['MOOPCBGB_05234'] False
# 3592
# 5193_8_2.contig00030 ['MLKBEPLK_03626'] False
# 5299_7_4.contig00102 ['MOOPCBGB_04130'] False
# 5197_2_1.contig00031 ['PDEDMGPD_04033'] False
# 5197_7_4.contig00022 ['IMGDPOBN_03170', 'IMGDPOBN_03171', 'IMGDPOBN_03172'] False
# 5150_1_3.contig00006 ['AOMCCKAJ_01660', 'AOMCCKAJ_01661'] False
# 5197_7_5.contig00009 ['EHMCBADO_02394'] False
# 5235_2_1.contig00142 [] False
# 5150_2_2.contig00001 ['ILAAFBJJ_00065'] False
# 5235_5_12.contig00265 ['KKAGLBML_04142'] False
# 5150_3_5.contig00003 ['JGFEPBDE_00570'] False
# 5235_6_11.contig00051 ['NNHDGMCP_01684'] False
# 5151_2_6.contig00005 ['NALFBGJE_01010'] False
# 5235_6_11.contig00051 ['NNHDGMCP_01685'] False
# 5151_6_6.contig00007 ['NJAAJKJA_01712', 'NJAAJKJA_01713'] False
# 5235_6_12.contig00535 ['LIDJBJFH_05406'] False
# 5193_1_5.contig00037 ['AHIKKBJF_03895'] False
# 5299_1_3.contig00022 ['OBOFFKJP_01427'] False
# 5193_2_6.contig00006 ['FGIHKDBE_01193'] False
# 3876
# 5235_6_6.contig00740 ['LNOJILEH_05486'] True
# 5299_1_3.contig00015 ['OBOFFKJP_01133'] True
# 5299_7_4.contig00017 [] True
# 5150_1_3.contig00010 ['AOMCCKAJ_02364'] True
# 5150_2_2.contig00014 [] True
# 5150_3_5.contig00013 ['JGFEPBDE_02069'] True
# 5151_2_6.contig00010 [] True
# 5151_6_6.contig00008 ['NJAAJKJA_01866'] True
# 5193_1_5.contig00006 ['AHIKKBJF_01086'] True
# 5193_2_6.contig00011 [] True
# 5193_8_2.contig00001 ['MLKBEPLK_00064'] True
# 5197_2_1.contig00003 [] True
# 5197_7_4.contig00021 ['IMGDPOBN_03074'] True
# 5197_7_5.contig00002 ['EHMCBADO_00425'] True
# 5235_1_4.contig00352 ['MGBABOJF_03753'] True
# 5235_2_1.contig00684 [] True
# 5235_5_12.contig00680 [] True
# 5235_5_4.contig00100 ['LLOJMOCI_02339'] True
# 5235_6_11.contig00128 [] True
# 5235_6_12.contig00035 ['LIDJBJFH_01266'] True
# 1550
# 5235_6_6.contig00048 ['LNOJILEH_01323'] True
# 5299_1_3.contig00082 ['OBOFFKJP_03168'] True
# 5299_7_4.contig00059 ['MOOPCBGB_02971', 'MOOPCBGB_02972'] True
# 5150_1_3.contig00015 ['AOMCCKAJ_03078'] True
# 5150_2_2.contig00012 ['ILAAFBJJ_02612'] True
# 5150_3_5.contig00011 ['JGFEPBDE_01820', 'JGFEPBDE_01821', 'JGFEPBDE_01822'] True
# 5151_2_6.contig00004 ['NALFBGJE_00951'] True
# 5151_6_6.contig00002 ['NJAAJKJA_00466', 'NJAAJKJA_00467'] True
# 5193_1_5.contig00001 ['AHIKKBJF_00043', 'AHIKKBJF_00044'] True
# 5193_2_6.contig00002 ['FGIHKDBE_00321'] True
# 5193_8_2.contig00001 ['MLKBEPLK_00294'] True
# 5197_2_1.contig00002 ['PDEDMGPD_00508', 'PDEDMGPD_00509'] True
# 5197_7_4.contig00001 ['IMGDPOBN_00161'] True
# 5197_7_5.contig00002 ['EHMCBADO_00611'] True
# 5235_1_4.contig00428 ['MGBABOJF_04146'] True
# 5235_2_1.contig00020 ['IJODNBMD_00790'] True
# 5235_5_12.contig00145 ['KKAGLBML_03018'] True
# 5235_5_4.contig00020 ['LLOJMOCI_00762'] True
# 5235_6_11.contig00008 ['NNHDGMCP_00388'] True
# 5235_6_12.contig00118 ['LIDJBJFH_02740'] True
# 3593
# 5151_2_6.contig00028 ['NALFBGJE_03185'] False
# 5150_2_2.contig00002 ['ILAAFBJJ_00460'] False
# 5197_7_5.contig00014 ['EHMCBADO_03162'] False
# 5235_1_4.contig00243 [] False
# 7199
# 5235_5_4.contig00642 ['LLOJMOCI_05599'] False
# 5235_6_11.contig00275 ['NNHDGMCP_04432'] False
# 5235_6_6.contig00309 ['LNOJILEH_04087'] False
# 5235_6_6.contig00677 ['LNOJILEH_05396'] False
# 5299_1_3.contig00085 ['OBOFFKJP_03240'] False
# 5299_1_3.contig00153 ['OBOFFKJP_04319'] False
# 5299_7_4.contig00034 ['MOOPCBGB_02057'] False
# 5150_1_3.contig00013 [] False
# 5150_2_2.contig00017 ['ILAAFBJJ_03325'] False
# 5150_3_5.contig00031 ['JGFEPBDE_03510'] False
# 5151_2_6.contig00001 ['NALFBGJE_00133'] False
# 5151_6_6.contig00001 [] False
# 5193_1_5.contig00003 [] False
# 5193_2_6.contig00051 [] False
# 5193_8_2.contig00087 ['MLKBEPLK_05453'] False
# 5197_2_1.contig00001 [] False
# 5197_7_4.contig00002 [] False
# 5197_7_5.contig00001 ['EHMCBADO_00130'] False
# 5235_2_1.contig00129 [] False
# 5649
# 5235_1_4.contig00029 ['MGBABOJF_00748'] True
# 5235_2_1.contig00773 [] True
# 5235_5_12.contig00790 [] True
# 5235_5_4.contig00173 ['LLOJMOCI_03286'] True
# 5235_6_11.contig00233 [] True
# 5235_6_12.contig00123 [] True
# 5235_6_6.contig00906 ['LNOJILEH_05607'] True
# 5299_1_3.contig00020 ['OBOFFKJP_01386'] True
# 5299_7_4.contig00109 [] True
# 5150_1_3.contig00013 [] True
# 5150_2_2.contig00017 ['ILAAFBJJ_03375'] True
# 5150_3_5.contig00027 ['JGFEPBDE_03249'] True
# 5151_2_6.contig00001 ['NALFBGJE_00184'] True
# 5151_6_6.contig00001 [] True
# 5193_1_5.contig00005 ['AHIKKBJF_00882'] True
# 5193_2_6.contig00012 [] True
# 5193_8_2.contig00037 [] True
# 5197_2_1.contig00001 [] True
# 5197_7_4.contig00002 [] True
# 5197_7_5.contig00001 ['EHMCBADO_00190'] True
# 3877
# 5150_1_3.contig00061 ['AOMCCKAJ_05177'] False
# 5151_2_6.contig00190 [] False
# 5235_6_12.contig00640 ['LIDJBJFH_05610'] False
# 5150_3_5.contig00143 ['JGFEPBDE_05499'] False
# 2716
# 5235_5_4.contig00002 ['LLOJMOCI_00076'] True
# 5235_6_11.contig00035 [] True
# 5235_6_11.contig00380 [] True
# 5235_6_12.contig00071 [] True
# 5235_6_12.contig00396 ['LIDJBJFH_04932'] True
# 5235_6_6.contig00120 ['LNOJILEH_02389'] True
# 5235_6_6.contig00387 ['LNOJILEH_04536'] True
# 5299_1_3.contig00042 ['OBOFFKJP_02107'] True
# 5299_7_4.contig00129 ['MOOPCBGB_04589'] True
# 5150_1_3.contig00008 [] True
# 5150_2_2.contig00033 ['ILAAFBJJ_04776'] True
# 5150_3_5.contig00049 ['JGFEPBDE_04442'] True
# 5151_2_6.contig00014 ['NALFBGJE_02163'] True
# 5151_6_6.contig00019 ['NJAAJKJA_03372', 'NJAAJKJA_03373'] True
# 5193_1_5.contig00033 ['AHIKKBJF_03690'] True
# 5193_2_6.contig00017 ['FGIHKDBE_02686'] True
# 5193_8_2.contig00013 ['MLKBEPLK_02248'] True
# 5197_2_1.contig00017 ['PDEDMGPD_02888'] True
# 5197_7_4.contig00014 ['IMGDPOBN_02434'] True
# 5197_7_5.contig00018 ['EHMCBADO_03678'] True
# 5235_1_4.contig00224 ['MGBABOJF_02904'] True
# 5235_2_1.contig00014 ['IJODNBMD_00562'] True
# 5235_5_12.contig00256 ['KKAGLBML_04083'] True
# 4660
# 5197_2_1.contig00031 [] True
# 5197_7_4.contig00026 ['IMGDPOBN_03447'] True
# 5197_7_5.contig00009 ['EHMCBADO_02348'] True
# 5235_1_4.contig00647 ['MGBABOJF_04953'] True
# 5235_2_1.contig00042 [] True
# 5235_5_12.contig00061 [] True
# 5235_5_4.contig00071 [] True
# 5235_6_11.contig00038 [] True
# 5235_6_12.contig00134 [] True
# 5235_6_6.contig00002 ['LNOJILEH_00091'] True
# 5299_1_3.contig00022 ['OBOFFKJP_01436'] True
# 5299_7_4.contig00054 ['MOOPCBGB_02807'] True
# 5150_1_3.contig00006 ['AOMCCKAJ_01677'] True
# 5150_2_2.contig00001 [] True
# 5150_3_5.contig00003 [] True
# 5151_2_6.contig00005 [] True
# 5151_6_6.contig00007 ['NJAAJKJA_01656'] True
# 5193_1_5.contig00092 ['AHIKKBJF_05308'] True
# 5193_2_6.contig00006 ['FGIHKDBE_01113'] True
# 5193_8_2.contig00030 [] True
# 7200
# 5235_6_6.contig00006 [] False
# 5193_8_2.contig00036 ['MLKBEPLK_03991'] False
# 5151_2_6.contig00040 [] False
# 5197_7_4.contig00038 [] False
# 8565
# 5193_8_2.contig00025 ['MLKBEPLK_03303'] True
# 5197_2_1.contig00012 ['PDEDMGPD_02287'] True
# 5197_7_4.contig00025 ['IMGDPOBN_03353'] True
# 5197_7_5.contig00010 ['EHMCBADO_02628'] True
# 5235_1_4.contig00139 ['MGBABOJF_02217'] True
# 5235_2_1.contig00145 ['IJODNBMD_03004'] True
# 5235_5_12.contig00123 ['KKAGLBML_02756'] True
# 5235_5_4.contig00236 [] True
# 5235_6_11.contig00151 ['NNHDGMCP_03324'] True
# 5235_6_12.contig00200 ['LIDJBJFH_03658'] True
# 5235_6_6.contig00079 ['LNOJILEH_01832'] True
# 5299_1_3.contig00271 ['OBOFFKJP_05199'] True
# 5299_7_4.contig00038 ['MOOPCBGB_02222'] True
# 5150_1_3.contig00003 ['AOMCCKAJ_00842'] True
# 5150_2_2.contig00023 ['ILAAFBJJ_04033'] True
# 5150_3_5.contig00014 ['JGFEPBDE_02139'] True
# 5151_2_6.contig00041 ['NALFBGJE_03889'] True
# 5151_6_6.contig00014 ['NJAAJKJA_02739'] True
# 5193_1_5.contig00023 ['AHIKKBJF_03077', 'AHIKKBJF_03078'] True
# 5193_2_6.contig00050 ['FGIHKDBE_04632', 'FGIHKDBE_04633'] True
# 2717
# 5197_7_5.contig00001 ['EHMCBADO_00002'] False
# 5150_2_2.contig00006 ['ILAAFBJJ_01546'] False
# 5235_1_4.contig00064 ['MGBABOJF_01376'] False
# 6395
# 5193_2_6.contig00010 [] True
# 5193_8_2.contig00038 ['MLKBEPLK_04123'] True
# 5197_2_1.contig00009 ['PDEDMGPD_01908'] True
# 5197_7_4.contig00011 ['IMGDPOBN_02131'] True
# 5197_7_5.contig00004 ['EHMCBADO_01293'] True
# 5235_1_4.contig00210 ['MGBABOJF_02810'] True
# 5235_2_1.contig00043 ['IJODNBMD_01385'] True
# 5235_5_12.contig00072 ['KKAGLBML_01962'] True
# 5235_5_4.contig00124 ['LLOJMOCI_02708'] True
# 5235_6_11.contig00034 ['NNHDGMCP_01254'] True
# 5235_6_12.contig00096 ['LIDJBJFH_02407'] True
# 5235_6_6.contig00246 ['LNOJILEH_03635'] True
# 5235_6_6.contig00431 ['LNOJILEH_04728'] True
# 5299_1_3.contig00080 [] True
# 5299_7_4.contig00010 ['MOOPCBGB_00781'] True
# 5150_1_3.contig00001 ['AOMCCKAJ_00328'] True
# 5150_2_2.contig00026 [] True
# 5150_3_5.contig00001 ['JGFEPBDE_00151'] True
# 5151_2_6.contig00002 [] True
# 5151_6_6.contig00005 ['NJAAJKJA_01343'] True
# 5193_1_5.contig00009 [] True
# 4661
# 5193_8_2.contig00006 [] False
# 5197_2_1.contig00020 [] False
# 5235_1_4.contig00034 [] False
# 5235_6_11.contig00029 ['NNHDGMCP_01125'] False
# 5235_6_12.contig00005 ['LIDJBJFH_00269'] False
# 5650
# 5150_1_3.contig00023 ['AOMCCKAJ_03883'] False
# 5150_2_2.contig00024 ['ILAAFBJJ_04126'] False
# 5151_2_6.contig00044 [] False
# 5193_2_6.contig00022 [] False
# 5193_8_2.contig00023 [] False
# 5197_2_1.contig00026 ['PDEDMGPD_03676'] False
# 5197_7_4.contig00039 ['IMGDPOBN_04169'] False
# 5197_7_5.contig00017 ['EHMCBADO_03551'] False
# 5235_6_6.contig00212 ['LNOJILEH_03356'] False
# 7078
# 5151_6_6.contig00038 ['NJAAJKJA_04618'] True
# 5193_1_5.contig00043 ['AHIKKBJF_04170'] True
# 5193_2_6.contig00015 ['FGIHKDBE_02479', 'FGIHKDBE_02480'] True
# 5193_8_2.contig00002 ['MLKBEPLK_00610'] True
# 5197_2_1.contig00042 ['PDEDMGPD_04653'] True
# 5197_7_4.contig00043 ['IMGDPOBN_04334', 'IMGDPOBN_04335'] True
# 5197_7_5.contig00011 ['EHMCBADO_02859'] True
# 5235_1_4.contig00013 ['MGBABOJF_00419', 'MGBABOJF_00420'] True
# 5235_2_1.contig00321 [] True
# 5235_2_1.contig00609 ['IJODNBMD_05459'] True
# 5235_2_1.contig00609 ['IJODNBMD_05460'] True
# 5235_5_12.contig00170 ['KKAGLBML_03300'] True
# 5235_5_4.contig00524 ['LLOJMOCI_05330'] True
# 5235_6_11.contig00089 ['NNHDGMCP_02457', 'NNHDGMCP_02458'] True
# 5235_6_11.contig00317 [] True
# 5235_6_12.contig00018 ['LIDJBJFH_00775'] True
# 5235_6_6.contig00168 ['LNOJILEH_02946'] True
# 5235_6_6.contig00168 ['LNOJILEH_02947'] True
# 5235_6_6.contig00304 ['LNOJILEH_04059'] True
# 5299_1_3.contig00032 ['OBOFFKJP_01825'] True
# 5299_7_4.contig00041 ['MOOPCBGB_02348'] True
# 5150_1_3.contig00032 ['AOMCCKAJ_04446'] True
# 5150_2_2.contig00020 ['ILAAFBJJ_03725', 'ILAAFBJJ_03726'] True
# 5150_3_5.contig00076 ['JGFEPBDE_05151'] True
# 5151_2_6.contig00057 ['NALFBGJE_04573'] True
# 301
# 5150_1_3.contig00017 ['AOMCCKAJ_03359'] True
# 5150_2_2.contig00022 ['ILAAFBJJ_03989'] True
# 5150_3_5.contig00025 [] True
# 5151_2_6.contig00001 ['NALFBGJE_00024'] True
# 5151_6_6.contig00001 ['NJAAJKJA_00047'] True
# 5193_1_5.contig00005 ['AHIKKBJF_00880'] True
# 5193_2_6.contig00033 ['FGIHKDBE_03902'] True
# 5193_8_2.contig00005 ['MLKBEPLK_01119'] True
# 5197_2_1.contig00001 ['PDEDMGPD_00083'] True
# 5197_7_4.contig00005 [] True
# 5197_7_5.contig00001 ['EHMCBADO_00076', 'EHMCBADO_00077'] True
# 5235_1_4.contig00413 ['MGBABOJF_04083'] True
# 5235_2_1.contig00302 ['IJODNBMD_04331'] True
# 5235_5_12.contig00300 ['KKAGLBML_04386'] True
# 5235_5_4.contig00149 ['LLOJMOCI_03023'] True
# 5235_6_11.contig00115 ['NNHDGMCP_02852'] True
# 5235_6_12.contig00148 ['LIDJBJFH_03105'] True
# 5235_6_6.contig00381 ['LNOJILEH_04503'] True
# 5299_1_3.contig00012 ['OBOFFKJP_00999', 'OBOFFKJP_01000'] True
# 5299_7_4.contig00024 ['MOOPCBGB_01611'] True
# 4662
# 5151_2_6.contig00054 ['NALFBGJE_04444'] False
# 5235_6_6.contig00027 ['LNOJILEH_00884'] False
# 5193_8_2.contig00120 ['MLKBEPLK_05577'] False
# 1551
# 5150_1_3.contig00024 ['AOMCCKAJ_04003'] True
# 5150_2_2.contig00027 [] True
# 5150_3_5.contig00022 [] True
# 5151_2_6.contig00018 ['NALFBGJE_02509'] True
# 5151_6_6.contig00045 [] True
# 5193_1_5.contig00021 ['AHIKKBJF_02915'] True
# 5193_2_6.contig00047 [] True
# 5193_8_2.contig00022 ['MLKBEPLK_03058'] True
# 5197_2_1.contig00025 ['PDEDMGPD_03627'] True
# 5197_7_4.contig00023 ['IMGDPOBN_03244'] True
# 5197_7_5.contig00023 [] True
# 5235_1_4.contig01050 ['MGBABOJF_05685'] True
# 5235_2_1.contig00028 ['IJODNBMD_00997'] True
# 5235_5_12.contig00077 ['KKAGLBML_02047'] True
# 5235_5_4.contig00005 ['LLOJMOCI_00247'] True
# 5235_6_11.contig00062 ['NNHDGMCP_01938'] True
# 5235_6_12.contig00085 [] True
# 5235_6_6.contig00589 ['LNOJILEH_05218'] True
# 5299_1_3.contig00116 ['OBOFFKJP_03801'] True
# 5299_7_4.contig00020 [] True
# 302
# 5150_2_2.contig00001 ['ILAAFBJJ_00214'] False
# 5235_1_4.contig00341 [] False
# 5197_7_5.contig00016 ['EHMCBADO_03450'] False
# 5651
# 5193_2_6.contig00146 [] False
# 5197_2_1.contig00022 ['PDEDMGPD_03294'] False
# 5235_6_11.contig00001 [] False
# 5235_6_12.contig00727 ['LIDJBJFH_05707'] False
# 5235_6_6.contig00027 ['LNOJILEH_00898'] False
# 7079
# 5150_3_5.contig00034 ['JGFEPBDE_03701'] False
# 5193_2_6.contig00037 ['FGIHKDBE_04081'] False
# 5193_8_2.contig00055 ['MLKBEPLK_04882'] False
# 5197_2_1.contig00046 ['PDEDMGPD_04794', 'PDEDMGPD_04795'] False
# 5235_1_4.contig00004 ['MGBABOJF_00170'] False
# 3594
# 5150_1_3.contig00001 ['AOMCCKAJ_00082'] True
# 5150_2_2.contig00015 ['ILAAFBJJ_03114'] True
# 5150_3_5.contig00001 ['JGFEPBDE_00079'] True
# 5150_3_5.contig00001 ['JGFEPBDE_00080'] True
# 5151_2_6.contig00002 ['NALFBGJE_00328'] True
# 5151_6_6.contig00041 ['NJAAJKJA_04765'] True
# 5193_1_5.contig00024 ['AHIKKBJF_03175'] True
# 5193_2_6.contig00010 ['FGIHKDBE_01798'] True
# 5193_8_2.contig00029 ['MLKBEPLK_03613'] True
# 5197_2_1.contig00023 ['PDEDMGPD_03440'] True
# 5197_7_4.contig00041 ['IMGDPOBN_04252'] True
# 5197_7_5.contig00015 ['EHMCBADO_03325'] True
# 5235_1_4.contig00429 ['MGBABOJF_04152'] True
# 5235_2_1.contig00282 ['IJODNBMD_04200'] True
# 5235_5_12.contig00272 ['KKAGLBML_04194'] True
# 5235_5_4.contig00306 ['LLOJMOCI_04376'] True
# 5235_6_11.contig00166 ['NNHDGMCP_03509'] True
# 5235_6_12.contig00447 ['LIDJBJFH_05135'] True
# 5235_6_6.contig00370 ['LNOJILEH_04446'] True
# 5299_1_3.contig00225 ['OBOFFKJP_04935'] True
# 5299_7_4.contig00009 ['MOOPCBGB_00695', 'MOOPCBGB_00696'] True
# 3878
# 5150_1_3.contig00018 ['AOMCCKAJ_03467'] True
# 5150_2_2.contig00025 ['ILAAFBJJ_04251'] True
# 5150_3_5.contig00015 [] True
# 5151_2_6.contig00021 ['NALFBGJE_02761'] True
# 5151_6_6.contig00021 [] True
# 5193_1_5.contig00019 ['AHIKKBJF_02748'] True
# 5193_2_6.contig00020 ['FGIHKDBE_02980'] True
# 5193_8_2.contig00015 [] True
# 5197_2_1.contig00019 ['PDEDMGPD_03108'] True
# 5197_7_4.contig00016 [] True
# 5197_7_5.contig00022 ['EHMCBADO_04112'] True
# 5235_1_4.contig00091 [] True
# 5235_2_1.contig00258 ['IJODNBMD_04036'] True
# 5235_5_12.contig00158 [] True
# 5235_5_4.contig00019 [] True
# 5235_6_11.contig00163 [] True
# 5235_6_12.contig00276 ['LIDJBJFH_04256'] True
# 5235_6_6.contig00258 ['LNOJILEH_03734'] True
# 5299_1_3.contig00005 [] True
# 5299_7_4.contig00075 ['MOOPCBGB_03492'] True
# 303
# 5197_7_5.contig00050 [] False
# 5299_7_4.contig00061 ['MOOPCBGB_03064'] False
# 5235_2_1.contig00029 ['IJODNBMD_01039'] False
# 5652
# 5235_5_12.contig00688 ['KKAGLBML_05550'] False
# 5235_6_12.contig00632 ['LIDJBJFH_05596'] False
# 5299_7_4.contig00263 ['MOOPCBGB_05463'] False
# 5193_2_6.contig00123 ['FGIHKDBE_05412'] False
# 5197_7_4.contig00100 [] False
# 7201
# 5150_1_3.contig00007 ['AOMCCKAJ_01891'] True
# 5150_2_2.contig00008 [] True
# 5150_3_5.contig00043 ['JGFEPBDE_04213'] True
# 5151_2_6.contig00030 [] True
# 5151_6_6.contig00006 ['NJAAJKJA_01517'] True
# 5193_1_5.contig00020 ['AHIKKBJF_02768'] True
# 5193_2_6.contig00013 ['FGIHKDBE_02189'] True
# 5193_8_2.contig00018 ['MLKBEPLK_02678'] True
# 5197_2_1.contig00010 [] True
# 5197_7_4.contig00010 ['IMGDPOBN_01987'] True
# 5197_7_5.contig00057 ['EHMCBADO_05442'] True
# 5235_1_4.contig00112 ['MGBABOJF_01934'] True
# 5235_2_1.contig00266 [] True
# 5235_5_12.contig00060 ['KKAGLBML_01733'] True
# 5235_5_4.contig00064 ['LLOJMOCI_01738'] True
# 5235_6_11.contig00153 ['NNHDGMCP_03364'] True
# 5235_6_12.contig00104 ['LIDJBJFH_02533'] True
# 5235_6_6.contig00124 ['LNOJILEH_02449'] True
# 5299_1_3.contig00096 [] True
# 5299_7_4.contig00016 ['MOOPCBGB_01149'] True
# 304
# 5197_2_1.contig00003 [] False
# 5193_8_2.contig00001 ['MLKBEPLK_00102'] False
# 2718
# 5150_1_3.contig00008 [] True
# 5150_2_2.contig00013 [] True
# 5150_3_5.contig00055 ['JGFEPBDE_04668'] True
# 5151_2_6.contig00059 ['NALFBGJE_04611'] True
# 5151_6_6.contig00022 ['NJAAJKJA_03642'] True
# 5193_1_5.contig00027 ['AHIKKBJF_03330'] True
# 5193_2_6.contig00003 [] True
# 5193_8_2.contig00059 ['MLKBEPLK_04988'] True
# 5197_2_1.contig00050 [] True
# 5197_7_4.contig00049 ['IMGDPOBN_04503'] True
# 5197_7_5.contig00056 ['EHMCBADO_05420'] True
# 5235_1_4.contig00800 ['MGBABOJF_05330'] True
# 5235_2_1.contig00279 [] True
# 5235_5_12.contig00034 ['KKAGLBML_01140'] True
# 5235_5_4.contig00179 [] True
# 5235_6_11.contig00094 [] True
# 5235_6_12.contig00114 [] True
# 5235_6_6.contig00233 ['LNOJILEH_03535'] True
# 5299_1_3.contig00114 [] True
# 5299_7_4.contig00065 ['MOOPCBGB_03161'] True

# %% [markdown]
# ## Extracting core from Panaroo

# %%
panaroo_dir = "/home/pampuch/studia/magisterka/test_data/klebsiella_subset_old/panaroo_out/"
panaroo_model = panaroo_parser.parse_panaroo_output(panaroo_dir, gff_dir)

# %%
def panaroo_annotations_to_csv(pg, gff_dir, csv_name = "panaroo_annotations_summary.csv"):
    res_csv = open(csv_name, "w")
    res_csv.write("cluster name,cluster size,core status,seq name,CDS\n")
    res_csv.flush()
    pg.detect_soft_core()
    # pg.map_to_gff(gff_dir)
    for seq_coll in pg.seq_collections:
        id = seq_coll.cluster_name
        clust_size = len(seq_coll)
        core_status = seq_coll.soft_core
        for seq in seq_coll.sequences:
            # annotation len is also an iimportant aspect, but can be easily retrived from gff file
            # print(seq.seq_name, [ann.annotation_id for ann in seq.mapped_annotations], seq_coll.soft_core)
            annots = ";".join([ann_id for ann_id in seq.annotation_ids])
            res_csv.write(f"{id},{clust_size},{core_status},{seq.seq_name},{annots}\n")
            res_csv.flush()
    res_csv.close()

# %%
panaroo_annotations_to_csv(panaroo_model, gff_dir)
