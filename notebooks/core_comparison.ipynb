# %%
from pgtools import panaroo_parser
from pgtools.gff_parser import parse_gff, parse_GFFs_dir, Pangenome_Gffs
from pgtools.gfa_parser import parse_gfa1
from pgtools.maf_parser import parse_maf, MAF
from pgtools.utils import intersection_len, contains
from pgtools.pangenome import Pangenome
import os
import argparse
from Bio.Seq import Seq

# %%
maf_dir = "/home/pampuch/studia/magisterka/test_data/klebsiella_subset_old/panaroo_new.maf"
gff_dir = "/home/pampuch/studia/magisterka/test_data/klebsiella_subset_old/gff/"

# %%
pg_maf = parse_maf(maf_dir)
pg_maf = MAF(list(pg_maf.seq_collections)[:30])

# %%
pg_maf.detect_soft_core()

# %%
for seq_coll in pg_maf.seq_collections:
    print(seq_coll.soft_core)
# Out:
# False
# False
# True
# False
# True
# False
# False
# True
# False
# False
# True
# False
# False
# True
# False
# True
# False
# False
# False
# False
# True
# True
# False
# True
# False
# True
# False
# True
# True
# False

# %%
pg_maf.map_to_gff(gff_dir)

# %%
def annotations_to_csv(pg, gff_dir, csv_name = "annotations_summary.csv"):
    res_csv = open(csv_name, "w")
    res_csv.write("cluster id,cluster size,core status,seq name,mapped annotations\n")
    res_csv.flush()
    pg.detect_soft_core()
    pg.map_to_gff(gff_dir)
    for seq_coll in pg.seq_collections:
        id = seq_coll.id
        clust_size = len(seq_coll)
        core_status = seq_coll.soft_core
        for seq in seq_coll.sequences:
            # annotation len is also an iimportant aspect, but can be easily retrived from gff file
            # print(seq.seq_name, [ann.annotation_id for ann in seq.mapped_annotations], seq_coll.soft_core)
            annots = ";".join([ann.annotation_id for ann in seq.mapped_annotations])
            res_csv.write(f"{id},{clust_size},{core_status},{seq.seq_name},{annots}\n")
            res_csv.flush()
    res_csv.close()

# %%
annotations_to_csv(pg_maf, gff_dir)

# %%
for seq_coll in pg_maf.seq_collections:
    print(seq_coll.id)
    for seq in seq_coll.sequences:
        print(seq.seq_name, [ann.annotation_id for ann in seq.mapped_annotations], seq_coll.soft_core)
# Out:
# 1812
# 5193_8_2.contig00013 [] False
# 5299_7_4.contig00074 ['MOOPCBGB_03461', 'MOOPCBGB_03461'] False
# 5197_2_1.contig00017 [] False
# 5197_7_4.contig00014 ['IMGDPOBN_02460', 'IMGDPOBN_02460'] False
# 5150_1_3.contig00008 ['AOMCCKAJ_02145', 'AOMCCKAJ_02145'] False
# 5197_7_5.contig00018 ['EHMCBADO_03703', 'EHMCBADO_03703'] False
# 5235_1_4.contig00241 ['MGBABOJF_03034', 'MGBABOJF_03034'] False
# 5150_2_2.contig00033 ['ILAAFBJJ_04801', 'ILAAFBJJ_04801'] False
# 5235_2_1.contig00014 [] False
# 5150_3_5.contig00049 ['JGFEPBDE_04468', 'JGFEPBDE_04468'] False
# 5235_5_4.contig00002 ['LLOJMOCI_00102', 'LLOJMOCI_00102'] False
# 5151_2_6.contig00014 ['NALFBGJE_02189', 'NALFBGJE_02189'] False
# 5235_6_12.contig00109 ['LIDJBJFH_02607', 'LIDJBJFH_02607'] False
# 5151_6_6.contig00019 [] False
# 5235_6_6.contig00049 ['LNOJILEH_01343', 'LNOJILEH_01343'] False
# 5193_1_5.contig00033 [] False
# 5299_1_3.contig00042 [] False
# 5193_2_6.contig00017 ['FGIHKDBE_02712', 'FGIHKDBE_02712'] False
# 3084
# 5235_1_4.contig00334 [] False
# 5197_7_5.contig00010 ['EHMCBADO_02525', 'EHMCBADO_02525'] False
# 5150_2_2.contig00023 [] False
# 1174
# 5299_7_4.contig00011 ['MOOPCBGB_00840', 'MOOPCBGB_00840'] True
# 5150_1_3.contig00014 ['AOMCCKAJ_03013', 'AOMCCKAJ_03013'] True
# 5150_2_2.contig00006 ['ILAAFBJJ_01586', 'ILAAFBJJ_01586'] True
# 5150_3_5.contig00004 ['JGFEPBDE_00812', 'JGFEPBDE_00812'] True
# 5151_2_6.contig00001 ['NALFBGJE_00031', 'NALFBGJE_00031'] True
# 5151_6_6.contig00001 ['NJAAJKJA_00113', 'NJAAJKJA_00113', 'NJAAJKJA_00114', 'NJAAJKJA_00114'] True
# 5193_1_5.contig00003 ['AHIKKBJF_00570', 'AHIKKBJF_00570'] True
# 5193_2_6.contig00005 ['FGIHKDBE_01009', 'FGIHKDBE_01009'] True
# 5193_8_2.contig00004 ['MLKBEPLK_00947', 'MLKBEPLK_00947'] True
# 5197_2_1.contig00001 ['PDEDMGPD_00120', 'PDEDMGPD_00120'] True
# 5197_7_4.contig00002 ['IMGDPOBN_00443', 'IMGDPOBN_00443', 'IMGDPOBN_00444', 'IMGDPOBN_00444'] True
# 5197_7_5.contig00001 ['EHMCBADO_00042', 'EHMCBADO_00042'] True
# 5235_1_4.contig00176 ['MGBABOJF_02538', 'MGBABOJF_02538'] True
# 5235_2_1.contig00137 ['IJODNBMD_02922', 'IJODNBMD_02922'] True
# 5235_5_12.contig00046 ['KKAGLBML_01422', 'KKAGLBML_01422'] True
# 5235_5_4.contig00056 ['LLOJMOCI_01595', 'LLOJMOCI_01595'] True
# 5235_6_11.contig00049 ['NNHDGMCP_01629', 'NNHDGMCP_01629'] True
# 5235_6_12.contig00198 ['LIDJBJFH_03645', 'LIDJBJFH_03645'] True
# 5235_6_6.contig00046 ['LNOJILEH_01286', 'LNOJILEH_01286'] True
# 5299_1_3.contig00023 ['OBOFFKJP_01478', 'OBOFFKJP_01478'] True
# 5134
# 5197_2_1.contig00056 ['PDEDMGPD_05084', 'PDEDMGPD_05084'] False
# 5193_8_2.contig00075 [] False
# 1690
# 5235_6_6.contig00528 ['LNOJILEH_05058', 'LNOJILEH_05058'] True
# 5235_6_6.contig00528 ['LNOJILEH_05059', 'LNOJILEH_05059'] True
# 5299_1_3.contig00124 ['OBOFFKJP_03918', 'OBOFFKJP_03918'] True
# 5299_7_4.contig00031 ['MOOPCBGB_01918', 'MOOPCBGB_01918'] True
# 5150_1_3.contig00013 ['AOMCCKAJ_02802', 'AOMCCKAJ_02802'] True
# 5150_2_2.contig00017 [] True
# 5150_3_5.contig00066 ['JGFEPBDE_04989', 'JGFEPBDE_04989', 'JGFEPBDE_04990', 'JGFEPBDE_04990', 'JGFEPBDE_04991', 'JGFEPBDE_04991'] True
# 5151_2_6.contig00001 ['NALFBGJE_00050', 'NALFBGJE_00050'] True
# 5151_6_6.contig00001 ['NJAAJKJA_00086', 'NJAAJKJA_00086'] True
# 5193_1_5.contig00005 ['AHIKKBJF_00910', 'AHIKKBJF_00910'] True
# 5193_2_6.contig00012 ['FGIHKDBE_02077', 'FGIHKDBE_02077'] True
# 5193_8_2.contig00005 ['MLKBEPLK_01158', 'MLKBEPLK_01158'] True
# 5197_2_1.contig00001 ['PDEDMGPD_00122', 'PDEDMGPD_00122'] True
# 5197_7_4.contig00005 [] True
# 5197_7_5.contig00001 ['EHMCBADO_00118', 'EHMCBADO_00118'] True
# 5235_1_4.contig00395 ['MGBABOJF_03989', 'MGBABOJF_03989'] True
# 5235_2_1.contig00632 ['IJODNBMD_05490', 'IJODNBMD_05490'] True
# 5235_5_12.contig00421 ['KKAGLBML_04957', 'KKAGLBML_04957'] True
# 5235_5_12.contig00421 ['KKAGLBML_04958', 'KKAGLBML_04958'] True
# 5235_5_4.contig00135 ['LLOJMOCI_02857', 'LLOJMOCI_02857'] True
# 5235_6_11.contig00467 ['NNHDGMCP_05331', 'NNHDGMCP_05331'] True
# 5993
# 5151_2_6.contig00068 ['NALFBGJE_04924', 'NALFBGJE_04924', 'NALFBGJE_04925', 'NALFBGJE_04925'] False
# 5151_6_6.contig00048 ['NJAAJKJA_05003', 'NJAAJKJA_05003'] False
# 5235_6_12.contig00022 [] False
# 5299_1_3.contig00048 [] False
# 5150_1_3.contig00050 ['AOMCCKAJ_04981', 'AOMCCKAJ_04981'] False
# 5150_3_5.contig00084 ['JGFEPBDE_05236', 'JGFEPBDE_05236', 'JGFEPBDE_05237', 'JGFEPBDE_05237'] False
# 1813
# 5235_6_6.contig00027 ['LNOJILEH_00884', 'LNOJILEH_00884'] False
# 5197_7_4.contig00056 [] False
# 2057
# 5235_6_11.contig00280 [] True
# 5235_6_12.contig00109 [] True
# 5235_6_6.contig00049 ['LNOJILEH_01348', 'LNOJILEH_01348'] True
# 5299_1_3.contig00259 ['OBOFFKJP_05132', 'OBOFFKJP_05132'] True
# 5299_7_4.contig00074 ['MOOPCBGB_03466', 'MOOPCBGB_03466'] True
# 5150_1_3.contig00008 [] True
# 5150_2_2.contig00033 ['ILAAFBJJ_04806', 'ILAAFBJJ_04806'] True
# 5150_3_5.contig00049 ['JGFEPBDE_04473', 'JGFEPBDE_04473'] True
# 5151_2_6.contig00014 ['NALFBGJE_02194', 'NALFBGJE_02194'] True
# 5151_6_6.contig00019 [] True
# 5193_1_5.contig00104 [] True
# 5193_2_6.contig00017 ['FGIHKDBE_02717', 'FGIHKDBE_02717'] True
# 5193_8_2.contig00013 [] True
# 5197_2_1.contig00017 [] True
# 5197_7_4.contig00014 ['IMGDPOBN_02465', 'IMGDPOBN_02465'] True
# 5197_7_5.contig00018 ['EHMCBADO_03708', 'EHMCBADO_03708'] True
# 5235_1_4.contig00372 [] True
# 5235_2_1.contig00341 ['IJODNBMD_04549', 'IJODNBMD_04549'] True
# 5235_5_12.contig00284 [] True
# 5235_5_4.contig00345 [] True
# 3085
# 5151_2_6.contig00022 ['NALFBGJE_02776', 'NALFBGJE_02776', 'NALFBGJE_02777', 'NALFBGJE_02777'] False
# 5150_2_2.contig00001 ['ILAAFBJJ_00260', 'ILAAFBJJ_00260'] False
# 5197_7_5.contig00025 ['EHMCBADO_04280', 'EHMCBADO_04280'] False
# 1691
# 5235_6_12.contig00009 ['LIDJBJFH_00463', 'LIDJBJFH_00463'] False
# 5150_2_2.contig00009 ['ILAAFBJJ_02026', 'ILAAFBJJ_02026'] False
# 6118
# 5235_1_4.contig00387 ['MGBABOJF_03950', 'MGBABOJF_03950'] True
# 5235_2_1.contig00221 [] True
# 5235_5_12.contig00086 ['KKAGLBML_02201', 'KKAGLBML_02201'] True
# 5235_5_4.contig00106 ['LLOJMOCI_02450', 'LLOJMOCI_02450'] True
# 5235_6_11.contig00221 ['NNHDGMCP_04036', 'NNHDGMCP_04036'] True
# 5235_6_12.contig00035 ['LIDJBJFH_01267', 'LIDJBJFH_01267'] True
# 5235_6_6.contig00219 ['LNOJILEH_03421', 'LNOJILEH_03421'] True
# 5299_1_3.contig00092 ['OBOFFKJP_03383', 'OBOFFKJP_03383'] True
# 5299_7_4.contig00101 [] True
# 5150_1_3.contig00022 ['AOMCCKAJ_03820', 'AOMCCKAJ_03820'] True
# 5150_2_2.contig00002 [] True
# 5150_3_5.contig00007 [] True
# 5151_2_6.contig00028 ['NALFBGJE_03203', 'NALFBGJE_03203'] True
# 5151_6_6.contig00013 [] True
# 5193_1_5.contig00028 ['AHIKKBJF_03421', 'AHIKKBJF_03421'] True
# 5193_2_6.contig00018 ['FGIHKDBE_02778', 'FGIHKDBE_02778'] True
# 5193_8_2.contig00010 ['MLKBEPLK_01937', 'MLKBEPLK_01937'] True
# 5197_2_1.contig00007 [] True
# 5197_7_4.contig00027 ['IMGDPOBN_03507', 'IMGDPOBN_03507'] True
# 5197_7_5.contig00014 [] True
# 1175
# 5151_2_6.contig00026 ['NALFBGJE_03065', 'NALFBGJE_03065'] False
# 5197_7_4.contig00017 ['IMGDPOBN_02705', 'IMGDPOBN_02705'] False
# 5235_1_4.contig00152 ['MGBABOJF_02340', 'MGBABOJF_02340'] False
# 5235_2_1.contig00081 ['IJODNBMD_02115', 'IJODNBMD_02115'] False
# 5235_5_12.contig00053 ['KKAGLBML_01572', 'KKAGLBML_01572'] False
# 5235_6_11.contig00052 [] False
# 5299_7_4.contig00108 ['MOOPCBGB_04233', 'MOOPCBGB_04233'] False
# 2058
# 5235_1_4.contig00011 [] False
# 5197_2_1.contig00016 [] False
# 5193_8_2.contig00043 ['MLKBEPLK_04413', 'MLKBEPLK_04413'] False
# 5197_7_5.contig00019 ['EHMCBADO_03713', 'EHMCBADO_03713'] False
# 3501
# 5197_7_4.contig00040 ['IMGDPOBN_04224', 'IMGDPOBN_04224'] True
# 5197_7_5.contig00035 ['EHMCBADO_04871', 'EHMCBADO_04871'] True
# 5235_1_4.contig00146 ['MGBABOJF_02284', 'MGBABOJF_02284'] True
# 5235_2_1.contig00526 ['IJODNBMD_05278', 'IJODNBMD_05278'] True
# 5235_5_12.contig00622 [] True
# 5235_5_4.contig00166 ['LLOJMOCI_03212', 'LLOJMOCI_03212'] True
# 5235_6_11.contig00481 ['NNHDGMCP_05371', 'NNHDGMCP_05371'] True
# 5235_6_12.contig00630 [] True
# 5235_6_6.contig00675 [] True
# 5299_1_3.contig00008 [] True
# 5299_7_4.contig00115 ['MOOPCBGB_04378', 'MOOPCBGB_04378'] True
# 5150_1_3.contig00030 ['AOMCCKAJ_04361', 'AOMCCKAJ_04361'] True
# 5150_2_2.contig00002 ['ILAAFBJJ_00713', 'ILAAFBJJ_00713'] True
# 5150_3_5.contig00012 ['JGFEPBDE_02005', 'JGFEPBDE_02005'] True
# 5151_2_6.contig00046 ['NALFBGJE_04154', 'NALFBGJE_04154'] True
# 5151_6_6.contig00034 ['NJAAJKJA_04449', 'NJAAJKJA_04449', 'NJAAJKJA_04450', 'NJAAJKJA_04450'] True
# 5193_1_5.contig00038 ['AHIKKBJF_03961', 'AHIKKBJF_03961'] True
# 5193_2_6.contig00038 ['FGIHKDBE_04166', 'FGIHKDBE_04166'] True
# 5193_8_2.contig00007 ['MLKBEPLK_01540', 'MLKBEPLK_01540'] True
# 5197_2_1.contig00011 ['PDEDMGPD_02220', 'PDEDMGPD_02220'] True
# 1176
# 5235_6_6.contig00393 ['LNOJILEH_04558', 'LNOJILEH_04558'] False
# 5197_7_4.contig00095 ['IMGDPOBN_05209', 'IMGDPOBN_05209'] False
# 4268
# 5193_2_6.contig00003 ['FGIHKDBE_00638', 'FGIHKDBE_00638'] True
# 5193_8_2.contig00039 [] True
# 5197_2_1.contig00037 ['PDEDMGPD_04378', 'PDEDMGPD_04378'] True
# 5197_7_4.contig00006 ['IMGDPOBN_01374', 'IMGDPOBN_01374'] True
# 5197_7_5.contig00013 ['EHMCBADO_03095', 'EHMCBADO_03095'] True
# 5235_1_4.contig00001 [] True
# 5235_2_1.contig00055 ['IJODNBMD_01625', 'IJODNBMD_01625'] True
# 5235_5_12.contig00001 ['KKAGLBML_00023', 'KKAGLBML_00023'] True
# 5235_5_4.contig00042 [] True
# 5235_6_11.contig00004 ['NNHDGMCP_00188', 'NNHDGMCP_00188'] True
# 5235_6_12.contig00053 ['LIDJBJFH_01664', 'LIDJBJFH_01664'] True
# 5235_6_6.contig00068 [] True
# 5299_1_3.contig00001 ['OBOFFKJP_00050', 'OBOFFKJP_00050'] True
# 5299_7_4.contig00040 [] True
# 5150_1_3.contig00011 ['AOMCCKAJ_02549', 'AOMCCKAJ_02549'] True
# 5150_2_2.contig00018 ['ILAAFBJJ_03526', 'ILAAFBJJ_03526'] True
# 5150_3_5.contig00009 [] True
# 5151_2_6.contig00019 [] True
# 5151_6_6.contig00011 ['NJAAJKJA_02378', 'NJAAJKJA_02378'] True
# 5193_1_5.contig00004 [] True
# 6119
# 5193_2_6.contig00052 [] False
# 5193_1_5.contig00105 ['AHIKKBJF_05412', 'AHIKKBJF_05412'] False
# 5235_5_4.contig00004 ['LLOJMOCI_00174', 'LLOJMOCI_00174'] False
# 2059
# 5235_5_12.contig00255 [] False
# 5235_5_4.contig00197 [] False
# 3502
# 5197_7_5.contig00030 ['EHMCBADO_04625', 'EHMCBADO_04625'] False
# 5235_1_4.contig00023 [] False
# 6616
# 5235_6_11.contig00086 [] False
# 5151_2_6.contig00107 ['NALFBGJE_05485', 'NALFBGJE_05485'] False
# 5235_6_12.contig00037 ['LIDJBJFH_01316', 'LIDJBJFH_01316'] False
# 5151_6_6.contig00042 ['NJAAJKJA_04805', 'NJAAJKJA_04805'] False
# 5235_6_6.contig00004 ['LNOJILEH_00150', 'LNOJILEH_00150'] False
# 5193_1_5.contig00008 ['AHIKKBJF_01412', 'AHIKKBJF_01412'] False
# 5299_1_3.contig00098 ['OBOFFKJP_03492', 'OBOFFKJP_03492'] False
# 5193_2_6.contig00004 ['FGIHKDBE_00778', 'FGIHKDBE_00778'] False
# 5299_7_4.contig00027 ['MOOPCBGB_01750', 'MOOPCBGB_01750'] False
# 5193_8_2.contig00009 ['MLKBEPLK_01754', 'MLKBEPLK_01754'] False
# 5197_2_1.contig00006 ['PDEDMGPD_01305', 'PDEDMGPD_01305'] False
# 5197_7_4.contig00009 [] False
# 5150_1_3.contig00012 ['AOMCCKAJ_02656', 'AOMCCKAJ_02656'] False
# 5235_2_1.contig00068 ['IJODNBMD_01882', 'IJODNBMD_01882'] False
# 5235_5_12.contig00132 ['KKAGLBML_02866', 'KKAGLBML_02866'] False
# 5150_3_5.contig00081 [] False
# 5235_5_4.contig00001 [] False
# 1049
# 5151_2_6.contig00026 [] True
# 5151_6_6.contig00037 [] True
# 5193_1_5.contig00049 [] True
# 5193_2_6.contig00029 ['FGIHKDBE_03631', 'FGIHKDBE_03631'] True
# 5193_8_2.contig00033 [] True
# 5197_2_1.contig00034 ['PDEDMGPD_04231', 'PDEDMGPD_04231'] True
# 5197_7_4.contig00017 [] True
# 5197_7_5.contig00003 ['EHMCBADO_00723', 'EHMCBADO_00723'] True
# 5235_1_4.contig00150 ['MGBABOJF_02320', 'MGBABOJF_02320'] True
# 5235_2_1.contig00100 [] True
# 5235_5_12.contig00445 ['KKAGLBML_05049', 'KKAGLBML_05049'] True
# 5235_5_4.contig00501 ['LLOJMOCI_05260', 'LLOJMOCI_05260'] True
# 5235_6_11.contig00349 [] True
# 5235_6_12.contig00456 ['LIDJBJFH_05171', 'LIDJBJFH_05171'] True
# 5235_6_6.contig00134 ['LNOJILEH_02571', 'LNOJILEH_02571'] True
# 5299_1_3.contig00310 ['OBOFFKJP_05342', 'OBOFFKJP_05342'] True
# 5299_7_4.contig00223 ['MOOPCBGB_05364', 'MOOPCBGB_05364'] True
# 5150_1_3.contig00026 [] True
# 5150_2_2.contig00003 ['ILAAFBJJ_00769', 'ILAAFBJJ_00769'] True
# 5150_3_5.contig00045 ['JGFEPBDE_04300', 'JGFEPBDE_04300'] True
# 7176
# 5151_2_6.contig00020 ['NALFBGJE_02667', 'NALFBGJE_02667'] True
# 5151_6_6.contig00007 ['NJAAJKJA_01784', 'NJAAJKJA_01784'] True
# 5193_1_5.contig00024 ['AHIKKBJF_03097', 'AHIKKBJF_03097', 'AHIKKBJF_03098', 'AHIKKBJF_03098'] True
# 5193_2_6.contig00006 ['FGIHKDBE_01234', 'FGIHKDBE_01234'] True
# 5193_8_2.contig00029 ['MLKBEPLK_03554', 'MLKBEPLK_03554'] True
# 5197_2_1.contig00023 ['PDEDMGPD_03383', 'PDEDMGPD_03383', 'PDEDMGPD_03384', 'PDEDMGPD_03384', 'PDEDMGPD_03385', 'PDEDMGPD_03385'] True
# 5197_7_4.contig00030 ['IMGDPOBN_03673', 'IMGDPOBN_03673'] True
# 5197_7_5.contig00009 ['EHMCBADO_02474', 'EHMCBADO_02474'] True
# 5235_1_4.contig00131 ['MGBABOJF_02139', 'MGBABOJF_02139'] True
# 5235_2_1.contig00109 ['IJODNBMD_02560', 'IJODNBMD_02560', 'IJODNBMD_02561', 'IJODNBMD_02561', 'IJODNBMD_02562', 'IJODNBMD_02562'] True
# 5235_5_12.contig00044 ['KKAGLBML_01382', 'KKAGLBML_01382'] True
# 5235_5_4.contig00090 ['LLOJMOCI_02201', 'LLOJMOCI_02201', 'LLOJMOCI_02202', 'LLOJMOCI_02202'] True
# 5235_6_11.contig00306 ['NNHDGMCP_04636', 'NNHDGMCP_04636'] True
# 5235_6_12.contig00107 ['LIDJBJFH_02575', 'LIDJBJFH_02575'] True
# 5235_6_6.contig00150 ['LNOJILEH_02745', 'LNOJILEH_02745', 'LNOJILEH_02746', 'LNOJILEH_02746', 'LNOJILEH_02747', 'LNOJILEH_02747'] True
# 5299_1_3.contig00140 ['OBOFFKJP_04138', 'OBOFFKJP_04138', 'OBOFFKJP_04139', 'OBOFFKJP_04139'] True
# 5299_7_4.contig00060 ['MOOPCBGB_03001', 'MOOPCBGB_03001'] True
# 5150_1_3.contig00001 ['AOMCCKAJ_00019', 'AOMCCKAJ_00019'] True
# 5150_2_2.contig00015 ['ILAAFBJJ_03043', 'ILAAFBJJ_03043'] True
# 5150_3_5.contig00001 ['JGFEPBDE_00019', 'JGFEPBDE_00019'] True
# 1177
# 5235_1_4.contig00054 [] False
# 5235_2_1.contig00004 ['IJODNBMD_00165', 'IJODNBMD_00165'] False
# 4632
# 5150_3_5.contig00046 [] True
# 5151_2_6.contig00023 ['NALFBGJE_02852', 'NALFBGJE_02852'] True
# 5151_6_6.contig00006 [] True
# 5193_1_5.contig00064 [] True
# 5193_2_6.contig00013 [] True
# 5193_8_2.contig00050 ['MLKBEPLK_04683', 'MLKBEPLK_04683'] True
# 5197_2_1.contig00043 [] True
# 5197_7_4.contig00024 ['IMGDPOBN_03255', 'IMGDPOBN_03255', 'IMGDPOBN_03256', 'IMGDPOBN_03256'] True
# 5197_7_5.contig00007 ['EHMCBADO_01961', 'EHMCBADO_01961'] True
# 5235_1_4.contig00424 ['MGBABOJF_04129', 'MGBABOJF_04129'] True
# 5235_2_1.contig00010 ['IJODNBMD_00448', 'IJODNBMD_00448'] True
# 5235_5_12.contig00092 [] True
# 5235_5_4.contig00436 ['LLOJMOCI_05019', 'LLOJMOCI_05019'] True
# 5235_6_11.contig00037 ['NNHDGMCP_01317', 'NNHDGMCP_01317'] True
# 5235_6_12.contig00051 ['LIDJBJFH_01629', 'LIDJBJFH_01629'] True
# 5235_6_6.contig00074 [] True
# 5299_1_3.contig00006 ['OBOFFKJP_00528', 'OBOFFKJP_00528'] True
# 5299_7_4.contig00280 ['MOOPCBGB_05479', 'MOOPCBGB_05479'] True
# 5150_1_3.contig00007 ['AOMCCKAJ_01785', 'AOMCCKAJ_01785'] True
# 5150_2_2.contig00008 ['ILAAFBJJ_01916', 'ILAAFBJJ_01916'] True
# 4507
# 5197_7_5.contig00031 ['EHMCBADO_04689', 'EHMCBADO_04689'] False
# 5235_2_1.contig00063 [] False
# 5150_2_2.contig00007 [] False
# 5235_5_12.contig00650 [] False
# 5150_3_5.contig00036 [] False
# 5235_5_4.contig00017 ['LLOJMOCI_00671', 'LLOJMOCI_00671'] False
# 5151_2_6.contig00008 ['NALFBGJE_01447', 'NALFBGJE_01447'] False
# 5235_6_11.contig00078 ['NNHDGMCP_02240', 'NNHDGMCP_02240'] False
# 5151_6_6.contig00009 ['NJAAJKJA_02044', 'NJAAJKJA_02044'] False
# 5235_6_6.contig00146 ['LNOJILEH_02697', 'LNOJILEH_02697'] False
# 5193_1_5.contig00010 [] False
# 5299_1_3.contig00033 ['OBOFFKJP_01842', 'OBOFFKJP_01842'] False
# 5193_2_6.contig00034 [] False
# 5299_7_4.contig00008 ['MOOPCBGB_00631', 'MOOPCBGB_00631'] False
# 5193_8_2.contig00002 ['MLKBEPLK_00409', 'MLKBEPLK_00409'] False
# 5197_2_1.contig00005 [] False
# 5150_1_3.contig00005 ['AOMCCKAJ_01413', 'AOMCCKAJ_01413'] False
# 5197_7_4.contig00059 ['IMGDPOBN_04781', 'IMGDPOBN_04781'] False
# 371
# 5150_2_2.contig00031 ['ILAAFBJJ_04675', 'ILAAFBJJ_04675'] True
# 5150_3_5.contig00023 ['JGFEPBDE_02990', 'JGFEPBDE_02990', 'JGFEPBDE_02991', 'JGFEPBDE_02991'] True
# 5151_2_6.contig00039 ['NALFBGJE_03801', 'NALFBGJE_03801', 'NALFBGJE_03802', 'NALFBGJE_03802'] True
# 5151_6_6.contig00065 ['NJAAJKJA_05343', 'NJAAJKJA_05343'] True
# 5193_1_5.contig00073 ['AHIKKBJF_05059', 'AHIKKBJF_05059'] True
# 5193_2_6.contig00008 ['FGIHKDBE_01601', 'FGIHKDBE_01601'] True
# 5193_8_2.contig00006 ['MLKBEPLK_01381', 'MLKBEPLK_01381'] True
# 5197_2_1.contig00030 ['PDEDMGPD_04021', 'PDEDMGPD_04021', 'PDEDMGPD_04022', 'PDEDMGPD_04022'] True
# 5197_7_4.contig00003 ['IMGDPOBN_00830', 'IMGDPOBN_00830'] True
# 5197_7_5.contig00032 ['EHMCBADO_04732', 'EHMCBADO_04732'] True
# 5235_1_4.contig00416 ['MGBABOJF_04098', 'MGBABOJF_04098'] True
# 5235_2_1.contig00053 ['IJODNBMD_01599', 'IJODNBMD_01599'] True
# 5235_5_12.contig00149 ['KKAGLBML_03065', 'KKAGLBML_03065'] True
# 5235_5_4.contig00241 [] True
# 5235_6_11.contig00002 [] True
# 5235_6_12.contig00138 ['LIDJBJFH_02994', 'LIDJBJFH_02994'] True
# 5235_6_6.contig00127 ['LNOJILEH_02485', 'LNOJILEH_02485'] True
# 5299_1_3.contig00031 ['OBOFFKJP_01783', 'OBOFFKJP_01783'] True
# 5299_7_4.contig00004 ['MOOPCBGB_00352', 'MOOPCBGB_00352'] True
# 5150_1_3.contig00028 ['AOMCCKAJ_04255', 'AOMCCKAJ_04255', 'AOMCCKAJ_04256', 'AOMCCKAJ_04256'] True
# 1050
# 5299_1_3.contig00011 [] False
# 5151_6_6.contig00032 ['NJAAJKJA_04321', 'NJAAJKJA_04321'] False
# 6242
# 5150_2_2.contig00015 ['ILAAFBJJ_03169', 'ILAAFBJJ_03169', 'ILAAFBJJ_03170', 'ILAAFBJJ_03170'] True
# 5150_3_5.contig00057 ['JGFEPBDE_04736', 'JGFEPBDE_04736'] True
# 5151_2_6.contig00020 ['NALFBGJE_02661', 'NALFBGJE_02661'] True
# 5151_6_6.contig00007 ['NJAAJKJA_01652', 'NJAAJKJA_01652'] True
# 5193_1_5.contig00042 ['AHIKKBJF_04100', 'AHIKKBJF_04100'] True
# 5193_2_6.contig00006 [] True
# 5193_8_2.contig00024 ['MLKBEPLK_03175', 'MLKBEPLK_03175'] True
# 5197_2_1.contig00028 ['PDEDMGPD_03816', 'PDEDMGPD_03816'] True
# 5197_7_4.contig00022 ['IMGDPOBN_03107', 'IMGDPOBN_03107', 'IMGDPOBN_03108', 'IMGDPOBN_03108'] True
# 5197_7_5.contig00009 ['EHMCBADO_02331', 'EHMCBADO_02331'] True
# 5235_1_4.contig00545 [] True
# 5235_1_4.contig00545 [] True
# 5235_2_1.contig00307 ['IJODNBMD_04359', 'IJODNBMD_04359'] True
# 5235_5_12.contig00147 ['KKAGLBML_03036', 'KKAGLBML_03036'] True
# 5235_5_12.contig00147 ['KKAGLBML_03037', 'KKAGLBML_03037'] True
# 5235_5_4.contig00315 ['LLOJMOCI_04423', 'LLOJMOCI_04423'] True
# 5235_6_11.contig00060 ['NNHDGMCP_01892', 'NNHDGMCP_01892'] True
# 5235_6_12.contig00263 ['LIDJBJFH_04158', 'LIDJBJFH_04158'] True
# 5235_6_6.contig00164 ['LNOJILEH_02903', 'LNOJILEH_02903'] True
# 5299_1_3.contig00194 ['OBOFFKJP_04720', 'OBOFFKJP_04720'] True
# 5299_7_4.contig00171 [] True
# 5150_1_3.contig00006 ['AOMCCKAJ_01600', 'AOMCCKAJ_01600'] True
# 8184
# 5150_1_3.contig00030 [] True
# 5150_2_2.contig00002 ['ILAAFBJJ_00688', 'ILAAFBJJ_00688'] True
# 5150_3_5.contig00012 [] True
# 5151_2_6.contig00046 ['NALFBGJE_04123', 'NALFBGJE_04123'] True
# 5151_6_6.contig00034 ['NJAAJKJA_04410', 'NJAAJKJA_04410'] True
# 5193_1_5.contig00038 [] True
# 5193_2_6.contig00038 [] True
# 5193_8_2.contig00007 ['MLKBEPLK_01504', 'MLKBEPLK_01504'] True
# 5197_2_1.contig00011 ['PDEDMGPD_02184', 'PDEDMGPD_02184'] True
# 5197_7_4.contig00040 ['IMGDPOBN_04193', 'IMGDPOBN_04193'] True
# 5197_7_5.contig00035 ['EHMCBADO_04846', 'EHMCBADO_04846'] True
# 5235_1_4.contig00073 ['MGBABOJF_01503', 'MGBABOJF_01503'] True
# 5235_2_1.contig00223 [] True
# 5235_5_12.contig00179 ['KKAGLBML_03393', 'KKAGLBML_03393', 'KKAGLBML_03394', 'KKAGLBML_03394', 'KKAGLBML_03395', 'KKAGLBML_03395'] True
# 5235_5_4.contig00175 ['LLOJMOCI_03314', 'LLOJMOCI_03314'] True
# 5235_6_11.contig00017 ['NNHDGMCP_00736', 'NNHDGMCP_00736'] True
# 5235_6_12.contig00046 ['LIDJBJFH_01529', 'LIDJBJFH_01529'] True
# 5235_6_6.contig00017 ['LNOJILEH_00622', 'LNOJILEH_00622'] True
# 5299_1_3.contig00007 ['OBOFFKJP_00667', 'OBOFFKJP_00667'] True
# 5299_7_4.contig00014 ['MOOPCBGB_01082', 'MOOPCBGB_01082'] True
# 5299_7_4.contig00014 ['MOOPCBGB_01083', 'MOOPCBGB_01083'] True
# 372
# 5235_6_12.contig00590 ['LIDJBJFH_05527', 'LIDJBJFH_05527'] False
# 5235_6_6.contig00627 [] False

# %% [markdown]
# ## Extracting core from Panaroo

# %%
panaroo_dir = "/home/pampuch/studia/magisterka/test_data/klebsiella_subset_old/panaroo_out/"
panaroo_model = panaroo_parser.parse_panaroo_output(panaroo_dir, gff_dir)

# %%
def panaroo_annotations_to_csv(pg, gff_dir, csv_name = "panaroo_annotations_summary.csv"):
    res_csv = open(csv_name, "w")
    res_csv.write("cluster name,cluster size,core status,seq name,CDS\n")
    res_csv.flush()
    pg.detect_soft_core()
    # pg.map_to_gff(gff_dir)
    for seq_coll in pg.seq_collections:
        id = seq_coll.cluster_name
        clust_size = len(seq_coll)
        core_status = seq_coll.soft_core
        for seq in seq_coll.sequences:
            # annotation len is also an iimportant aspect, but can be easily retrived from gff file
            # print(seq.seq_name, [ann.annotation_id for ann in seq.mapped_annotations], seq_coll.soft_core)
            annots = ";".join([ann_id for ann_id in seq.annotation_ids])
            res_csv.write(f"{id},{clust_size},{core_status},{seq.seq_name},{annots}\n")
            res_csv.flush()
    res_csv.close()

# %%
panaroo_annotations_to_csv(panaroo_model, gff_dir)

# %%
summary_dir = "/home/pampuch/studia/magisterka/gffs_summary/"

# %% [markdown]
# ## Klebsiella

# %%
import pandas as pd

# %%
common_contigs = os.path.join(summary_dir, "common_contig_pairs/klebsiella_subset/contig_pairs.csv")

# %%
df_pairs = pd.read_csv(common_contigs)

# %%
df_pairs
# Out:
#                      contig1                contig2
# 0       5197_2_1.contig00015   5235_2_1.contig00493
# 1       5150_2_2.contig00001  5235_6_12.contig00341
# 2       5151_6_6.contig00062   5193_8_2.contig00060
# 3       5197_7_5.contig00010   5235_2_1.contig00112
# 4       5235_2_1.contig00505   5299_1_3.contig00053
# ...                      ...                    ...
# 100712  5299_1_3.contig00124   5299_7_4.contig00031
# 100713  5193_1_5.contig00050   5299_1_3.contig00107
# 100714  5150_3_5.contig00056   5151_6_6.contig00024
# 100715  5193_1_5.contig00005   5235_1_4.contig00571
# 100716  5197_2_1.contig00023   5235_1_4.contig01103
#
# [100717 rows x 2 columns]

# %%
df_lens = pd.read_csv(os.path.join(summary_dir, "klebsiella_subset.csv"))

# %%
df_lens["sequence"] = df_lens["genome"] + "." + df_lens["contig"]
df_lens
# Out:
#           genome       contig  contig length  no. of annotations on contig  \
# 0      5235_5_12  contig00001          64326                            62
# 1      5235_5_12  contig00002          60612                            63
# 2      5235_5_12  contig00003          53131                            47
# 3      5235_5_12  contig00004          42928                            47
# 4      5235_5_12  contig00005          40521                            32
# ...          ...          ...            ...                           ...
# 15603   5235_6_6  contig01171             56                             0
# 15604   5235_6_6  contig01172             56                             0
# 15605   5235_6_6  contig01173             56                             0
# 15606   5235_6_6  contig01174             56                             0
# 15607   5235_6_6  contig01175             56                             0
#
#                     sequence
# 0      5235_5_12.contig00001
# 1      5235_5_12.contig00002
# 2      5235_5_12.contig00003
# 3      5235_5_12.contig00004
# 4      5235_5_12.contig00005
# ...                      ...
# 15603   5235_6_6.contig01171
# 15604   5235_6_6.contig01172
# 15605   5235_6_6.contig01173
# 15606   5235_6_6.contig01174
# 15607   5235_6_6.contig01175
#
# [15608 rows x 5 columns]

# %%
df_lens = df_lens.set_index("sequence")

# %%
df_lens
# Out:
#                           genome       contig  contig length  \
# sequence
# 5235_5_12.contig00001  5235_5_12  contig00001          64326
# 5235_5_12.contig00002  5235_5_12  contig00002          60612
# 5235_5_12.contig00003  5235_5_12  contig00003          53131
# 5235_5_12.contig00004  5235_5_12  contig00004          42928
# 5235_5_12.contig00005  5235_5_12  contig00005          40521
# ...                          ...          ...            ...
# 5235_6_6.contig01171    5235_6_6  contig01171             56
# 5235_6_6.contig01172    5235_6_6  contig01172             56
# 5235_6_6.contig01173    5235_6_6  contig01173             56
# 5235_6_6.contig01174    5235_6_6  contig01174             56
# 5235_6_6.contig01175    5235_6_6  contig01175             56
#
#                        no. of annotations on contig
# sequence
# 5235_5_12.contig00001                            62
# 5235_5_12.contig00002                            63
# 5235_5_12.contig00003                            47
# 5235_5_12.contig00004                            47
# 5235_5_12.contig00005                            32
# ...                                             ...
# 5235_6_6.contig01171                              0
# 5235_6_6.contig01172                              0
# 5235_6_6.contig01173                              0
# 5235_6_6.contig01174                              0
# 5235_6_6.contig01175                              0
#
# [15608 rows x 4 columns]

# %%
df_pairs["len1"] = ""
df_pairs["len2"] = ""
for row in df_pairs.iterrows():
    # print(df_lens.at[row[1]["contig1"], "contig length"])
    # print(row[0])
    df_pairs.at[row[0],"len1"] = df_lens.at[row[1]["contig1"], "contig length"]
    df_pairs.at[row[0],"len2"] = df_lens.at[row[1]["contig2"], "contig length"]

# %%
df_pairs.sort_values(["len1","len2"], ascending = [False, False])
# Out:
#                     contig1                contig2    len1    len2
# 60682  5150_1_3.contig00001   5151_6_6.contig00002  520083  382901
# 16559  5150_1_3.contig00001   5197_7_5.contig00004  520083  339044
# 43442  5150_1_3.contig00001   5150_3_5.contig00001  520083  309492
# 79207  5150_1_3.contig00001   5151_2_6.contig00002  520083  256313
# 3411   5150_1_3.contig00001   5197_7_5.contig00009  520083  216796
# ...                     ...                    ...     ...     ...
# 46582  5150_3_5.contig00243   5299_1_3.contig00399     221     623
# 74187  5150_3_5.contig00243   5193_1_5.contig00196     221     466
# 34397  5150_3_5.contig00243  5235_6_11.contig00700     221     380
# 42910  5150_3_5.contig00243   5197_2_1.contig00206     221     310
# 78335  5197_7_4.contig00262  5235_5_12.contig00572     217    2040
#
# [100717 rows x 4 columns]

# %%
res_dir = "/home/pampuch/studia/magisterka/gffs_summary/common_with_lens/"

# %%
df_pairs.to_csv(os.path.join(res_dir, 'klebsiella_subset.csv'))

# %%
from tqdm import tqdm

# %%
for dataset in os.listdir(os.path.join(summary_dir, "common_contig_pairs")):
    print(dataset)
    common_contigs = os.path.join(summary_dir, f"common_contig_pairs/{dataset}/contig_pairs.csv")
    df_pairs = pd.read_csv(common_contigs)
    df_lens = pd.read_csv(os.path.join(summary_dir, f"{dataset}.csv"))
    df_lens["sequence"] = df_lens["genome"] + "." + df_lens["contig"]
    df_lens = df_lens.set_index("sequence")
    df_pairs["len1"] = ""
    df_pairs["len2"] = ""
    for row in tqdm(df_pairs.iterrows()):
        # print(df_lens.at[row[1]["contig1"], "contig length"])
        # print(row[0])
        df_pairs.at[row[0],"len1"] = df_lens.at[row[1]["contig1"], "contig length"]
        df_pairs.at[row[0],"len2"] = df_lens.at[row[1]["contig2"], "contig length"]
    df_pairs = df_pairs.sort_values(["len1","len2"], ascending = [False, False])
    df_pairs.to_csv(os.path.join(res_dir, f"{dataset}.csv"))
# Out:
# sim_gr_1e-11_lr_1e-12_mu_1e-15_rep1_fragmented
# 2015684it [02:21, 14203.30it/s]
# sim_gr_1e-11_lr_1e-12_mu_1e-15_rep1_contaminated
# 359097it [00:24, 14529.44it/s]
# klebsiella_subset
# 100717it [00:07, 14298.31it/s]
# sim_gr_1e-11_lr_1e-12_mu_1e-15_rep1
# 302510it [00:21, 14217.83it/s]
# sim_gr_1e-12_lr_1e-12_mu_1e-14_rep1
# 321504it [00:22, 14490.84it/s]
# sim_gr_1e-11_lr_1e-12_mu_1e-14_rep1
# 91331it [00:06, 14857.23it/s]
# GPSC_subset
# 15880it [00:01, 15016.22it/s]

# %%
df = pd.read_csv(os.path.join(res_dir, "GPSC_subset.csv"))

# %%
df
# Out:
#        Unnamed: 0                                        contig1  \
# 0            3596  22841_3_158.velvet.ERS1699832_SC_contig000001
# 1           15475  22841_3_158.velvet.ERS1699832_SC_contig000001
# 2            3244  22841_3_158.velvet.ERS1699832_SC_contig000001
# 3           14237  22841_3_158.velvet.ERS1699832_SC_contig000001
# 4            7266  22841_3_158.velvet.ERS1699832_SC_contig000001
# ...           ...                                            ...
# 15875        2690    15841_4_17.velvet.ERS639860_SC_contig000232
# 15876        3329    15841_4_17.velvet.ERS639860_SC_contig000232
# 15877        8443    15841_4_17.velvet.ERS639860_SC_contig000232
# 15878        9379    15841_4_17.velvet.ERS639860_SC_contig000232
# 15879         944    15841_4_17.velvet.ERS639860_SC_contig000232
#
#                                             contig2    len1    len2
# 0               23164_8_137.velvet._SC_contig000001  413792  385873
# 1               23164_8_137.velvet._SC_contig000002  413792  306798
# 2       22841_3_7.velvet.ERS1699673_SC_contig000002  413792  270780
# 3      22841_3_20.velvet.ERS1699686_SC_contig000001  413792  270333
# 4                23164_8_98.velvet._SC_contig000001  413792  269971
# ...                                             ...     ...     ...
# 15875   15841_4_38.velvet.ERS639881_SC_contig000001     301  275841
# 15876  17870_7_102.velvet.ERS725745_SC_contig000002     301  221843
# 15877   17870_7_11.velvet.ERS725493_SC_contig000004     301  178059
# 15878   17794_8_81.velvet.ERS719881_SC_contig000013     301   80577
# 15879   19341_2_35.velvet.ERS813179_SC_contig000019     301   29253
#
# [15880 rows x 5 columns]

# %%
df[:10]
# Out:
#    Unnamed: 0                                        contig1  \
# 0        3596  22841_3_158.velvet.ERS1699832_SC_contig000001
# 1       15475  22841_3_158.velvet.ERS1699832_SC_contig000001
# 2        3244  22841_3_158.velvet.ERS1699832_SC_contig000001
# 3       14237  22841_3_158.velvet.ERS1699832_SC_contig000001
# 4        7266  22841_3_158.velvet.ERS1699832_SC_contig000001
# 5        9914  22841_3_158.velvet.ERS1699832_SC_contig000001
# 6        4057  22841_3_158.velvet.ERS1699832_SC_contig000001
# 7        3848  22841_3_158.velvet.ERS1699832_SC_contig000001
# 8       13266  22841_3_158.velvet.ERS1699832_SC_contig000001
# 9        9157  22841_3_158.velvet.ERS1699832_SC_contig000001
#
#                                         contig2    len1    len2
# 0           23164_8_137.velvet._SC_contig000001  413792  385873
# 1           23164_8_137.velvet._SC_contig000002  413792  306798
# 2   22841_3_7.velvet.ERS1699673_SC_contig000002  413792  270780
# 3  22841_3_20.velvet.ERS1699686_SC_contig000001  413792  270333
# 4            23164_8_98.velvet._SC_contig000001  413792  269971
# 5  22841_3_20.velvet.ERS1699686_SC_contig000002  413792  243230
# 6            23164_8_98.velvet._SC_contig000002  413792  243170
# 7   22841_3_7.velvet.ERS1699673_SC_contig000004  413792  187194
# 8  22841_3_20.velvet.ERS1699686_SC_contig000003  413792  187152
# 9            23164_8_98.velvet._SC_contig000003  413792  186961

# %%
top_dir = "/home/pampuch/studia/magisterka/gffs_summary/top_contigs"

# %%
for dir in os.listdir(res_dir):
    dataset = dir.split(".")[0]
    df = pd.read_csv(os.path.join(res_dir, dir))
    df[:20].to_csv(os.path.join(top_dir, dir))

# %%
df_small = pd.read_csv(os.path.join(top_dir, "klebsiella_subset.csv"))

# %%
df_small[["contig1", "contig2"]].to_numpy()
# Out:
# array([['5150_1_3.contig00001', '5151_6_6.contig00002'],
#        ['5150_1_3.contig00001', '5197_7_5.contig00004'],
#        ['5150_1_3.contig00001', '5150_3_5.contig00001'],
#        ['5150_1_3.contig00001', '5151_2_6.contig00002'],
#        ['5150_1_3.contig00001', '5197_7_5.contig00009'],
#        ['5150_1_3.contig00001', '5150_1_3.contig00006'],
#        ['5150_1_3.contig00001', '5151_6_6.contig00005'],
#        ['5150_1_3.contig00001', '5197_2_1.contig00004'],
#        ['5150_1_3.contig00001', '5151_6_6.contig00007'],
#        ['5150_1_3.contig00001', '5193_2_6.contig00006'],
#        ['5150_1_3.contig00001', '5193_2_6.contig00007'],
#        ['5150_1_3.contig00001', '5150_2_2.contig00010'],
#        ['5150_1_3.contig00001', '5197_2_1.contig00009'],
#        ['5150_1_3.contig00001', '5197_7_4.contig00008'],
#        ['5150_1_3.contig00001', '5151_6_6.contig00010'],
#        ['5150_1_3.contig00001', '5150_2_2.contig00015'],
#        ['5150_1_3.contig00001', '5193_2_6.contig00010'],
#        ['5150_1_3.contig00001', '5193_8_2.contig00008'],
#        ['5150_1_3.contig00001', '5193_1_5.contig00009'],
#        ['5150_1_3.contig00001', '5197_7_4.contig00011']], dtype=object)
